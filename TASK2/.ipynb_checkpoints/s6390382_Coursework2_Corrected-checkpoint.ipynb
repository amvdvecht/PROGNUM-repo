# %% [markdown]
# # Coursework Set Week 2

# %% [markdown]
# **Common remarks**:
#
# * Deadline: Sunday at 23:59h for the week of this task
# * <font color='red'>Keep all the information in this template unaltered!</font>
#
# **Please fill in the following fields:**
#
# * Name: Anna van der Vecht
# * Username: amvecht
# * Student number: s6390382
# * Group (AS1, etc.): AS5
#
# -----

# %%
totalpoints = currentpoints = 0

# %% [markdown]
# ### Julian Date, a algorithm with some pitfalls (4 pt) <font color='red'><b>COURSEWORK</b></font>
#
# In the online article: [A one-line algorithm for Julian Date](http://adsabs.harvard.edu/full/1983IAPPP..13...16F)
# we find an old and very compact formula for programmable calculators to calculate a Julian Date given a day, month and year.
# A Julian Date is in fact a
# day number corresponding to the number of elapsed days since the beginning of a cycle of 7980 years.
# That makes it a useful tool to calculate how many days there are between two dates.
# The one-line algorithm is valid for the period that started in 1582 with the Gregorian calendar.
# The formula from the article is:
#
#
# ``JD = 367*Y -7*(Y+(M+9)/12)/4 - 3*((Y+(M-9)/7)/100 + 1)/4 + (275*M)/9 + D + 1721029-0.5``
#
# The article notes: **It is important to note that after all divisions in this expression only that portion of the
# quotient to the left of the decimal point is retained and that the quotient is not rounded off.**
#
# * Use your notebook to develop an implementation of this formula.
# * Then create a Python script called ``JD.py`` that asks a user to enter day, month and year. For this date, the script calculates the Julian Date (JD) and prints it. The day can be entered as a floating point number to allow for fractional days.
# * The article provides a test case: the Julian Date for January 4, 1700 is 2341975.5.
#   Use your code to get the correct result, and attach your screen shot in this notebook.&nbsp;
#
# Extend the program on the notebook, so that it can calculate the number of days between two dates in the Gregorian calendar. What is your age expressed in days?
#
# **Answers**:

# %%
print("In the following input put your day month and year of birth:") # Give explanaition about what to input

D, M, Y = input("Day of birth:"), input("Month of birth:"), input("Year of birth:") # Define varidables D, M, and Y as the input day, month and year of birth
print(f"The first birth date is: {D}-{M}-{Y}") # Print the put in date

D, M, Y = float(D), float(M), float(Y)                # Convert to floats to allow for partial days

JD = 367*Y -7*(Y+(M+9)/12)/4 - 3*((Y+(M-9)/7)/100 + 1)/4 + (275*M)/9 + D + 1721029-0.5 # Calculate the JD value with the formula from the question
print(f"Your JD value is: {JD}")     # Print the previously calculated JD value
# Out:
# In the following input put your day month and year of birth:
# Day of birth: 4
# Month of birth: 1
# Year of birth: 1700
# The first birth date is: 4-1-1700
# Your JD value is: 2341973.1057936507

# %% [markdown]
# Screenshot of terminal executing JD.py (before extending to calculate between 2 dates.)
#
# ![JD_1date_terminal.png](attachment:0d788d8f-ddf3-4ef8-ae96-e2015126d2f5.png)

# %%
# Give the input for the birthdate of the first person

print("In the following inputs put the day month and year of the birth of person 1:")

D1, M1, Y1 = input("Day of birth:"), input("Month of birth:"), input("Year of birth:")
print(f"The first birth date is: {D1}-{M1}-{Y1}")


D1, M1, Y1 = float(D1), float(M1), float(Y1)                # Convert to floats to allow for partial days

JD1 = 367*Y1 -7*(Y1+(M1+9)/12)/4 - 3*((Y1+(M1-9)/7)/100 + 1)/4 + (275*M1)/9 + D1 + 1721029-0.5
print(f"The JD value of person 1 is {JD1}")     # Calculate the JD value for person 1

# Extension to also calculate a second persons JD and the amount of days in between the first and second birthdate.
print("In the following inputs put the day month and year of the birth of person 2:")

D2, M2, Y2 = input("Day of birth:"), input("Month of birth:"), input("Year of birth:")
print(f"The second birth date is: {D2}-{M2}-{Y2}")     


D2, M2, Y2 = float(D2), float(M2), float(Y2)                # Convert to floats to allow for partial days

JD2 = 367*Y2 -7*(Y2+(M2+9)/12)/4 - 3*((Y2+(M2-9)/7)/100 + 1)/4 + (275*M2)/9 + D2 + 1721029-0.5
print(f"The JD value of person 1 is {JD2}")     # Calculate the JD value for person 2

JD1, JD2 = int(JD1), int(JD2)           # Convert to integers to get rid of any decimals without rounding off

Days = abs(JD2-JD1)                    # Calculate the days between two birth dates
print(f"The amount of days between the 2 dates given is: {Days} days")   # Print the final value
# Out:
# In the following inputs put the day month and year of the birth of person 1:
# Day of birth: 8
# Month of birth: 7
# Year of birth: 2000
# The first birth date is: 8-7-2000
# The JD value of person 1 is 2451732.307698413
# In the following inputs put the day month and year of the birth of person 2:

# %% [markdown]
# Link to repository: https://github.com/amvdvecht/PROGNUM-repo.git    (the JD notebook and .py file are under TASK2/Python_notebooks)

# %%
# Leave unaltered
totalpoints += 4
currentpoints += 0.0

# %% [markdown]
# ###  Calculating the roots of a second degree polynomial (3 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Use your notebook to develop the necessary code and then which solves for the roots
# of $f(x)=ax^2+bx+c$ for values of ``a``, ``b`` and ``c`` entered by a user of your program.
# All the required information related to this question is included in the notebook about conditions.
#
# You have to remember that
#
# $$f(x)=ax^2+bx+c$$
#
# has two solutions:
#
# $$x_1=\frac{-b + \sqrt{b^2-4ac}}{2a} \quad\text{and}\quad x_2=\frac{-b - \sqrt{b^2-4ac}}{2a}$$
#
# only if:
#
# $$\begin{split}D= b^2-4ac>0\end{split}$$
#
# It has one solution if $D == 0$ and no solutions (at least no real solutions) if $D < 0$.
#
# * Use the ``if,elif,else`` construct to print either two solutions, one solution or an message that no solutions
#  could be found.
# * Use f-strings for your output if there are solutions.
# * Include your code with an input example and its output in your notebook.
# * Use your notebook code to create a script called ``abc.py``.
# * On Terminal, run your python script, screenshot the result, and attach the it here.
#
# **Answer**:

# %%
# Correction: Included runnable code
from math import *
# Input values for a b and c and convert to float
a = float(input("Give a value for a:")) 
b = float(input("Give a value for b:"))
c = float(input("Give a value for c:"))

D = (b**2) - 4 * a * c # Calculate D with given function

# If D is bigger than 0 provide the two answers by calculating x using the formula from the question
if D > 0:
    x_1 = ( -b + sqrt( (b**2) - 4 * a * c) ) / (2 * a)
    x_2 = ( -b - sqrt( (b**2) - 4 * a * c) ) / (2 * a)
    print(f"f(x) = {a} x^2 + {b} x + {c}, with values a={a}, b={b}, c={c}, gives 2 solutions.")
    print(f"The solutions are x={x_1}, and x={x_2}")

# If D is smaller than 0 print that there are no solutions for the input a, b, and c
elif D < 0:
    print(f"There are no solutions for f(x), with the values a={a}, b={b}, c={c}")
    
# If D is 0 provide the answer by calculating x (- or + square root will give the same answer since you add or substract 0 so we only use 1 of them to calculate x)
elif D == 0:
    x = ( -b + sqrt( (b**2) - 4 * a * c) ) / (2 * a)
    print(f"There is only 1 solution for f(x), with values a={a}, b={b}, c={c}") 
    print(f"The solution is x={x}")
    
# Failsafe if anything goes wrong: ask user to resubmit values of a,b,c
else:
    print(f"It seems something went wrong, please retry with different values for a, b, and c")
# Out:
# Give a value for a: 1
# Give a value for b: -5
# Give a value for c: 6
# f(x) = 1.0 x^2 + -5.0 x + 6.0, with values a=1.0, b=-5.0, c=6.0, gives 2 solutions.
# The solutions are x=3.0, and x=2.0

# %% [markdown]
# ![abc_terminal.png](attachment:0d49a01c-b797-4e2a-971c-70d9a056bf0e.png)

# %%
# Leave unaltered
totalpoints += 3
currentpoints += 0.0

# %% [markdown]
# ### Uniqueness in lists using the `set` object (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given two lists with a number of gamma ray bursts per night for two different periods
#
# ```python
#     night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
#     night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
# ```
#
# Use Python sequence type `set` to create a **list**:
#
# 1. with values that are both in `night1` and `night2`.
# 1. with values that are the difference between `night1` and `night2`.
# 1. with values that contains all items from both sets, duplicates are excluded.
# 1. after an update of `night1` by removing all its elements that are not available in `night2`.
#
# **Answers**:

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]; night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]   # make two lists, night1 and night2
night1 = set(night1) ; night2 = set(night2) #Convert previous lists to sets

double = set.intersection(night1, night2) # Create new set with only the values that are in both night 1 and 2
double = list(double) # Convert set to list
print(f"The overlapping values are: {double}") # Print list "double"

diff = set.difference(night1, night2) # Create new set with values that are only in night1 and not night2
diff = list(diff) # Convert set to list
print(f"The different values are: {diff}") # Print list "diff"

both = night1.union(night2) # Create new set with all values in night 1 and night two (already excludes doubles because it is a set)
both = list(both) # Convert set to list
print(f"The full list including all items excluding doubles is: {both}") # Print list "both"

night1 = night1-(set.difference(night1, night2)) # Replace night1 with a version that only includes elements that are also available in night2
night1 = list(night1) # Convert set to list
print(f"List without things that are not in night2: {night1}") # Print the final list of the edited night1
# Out:
# The overlapping values are: [0, 1, 2, 3, 4]
# The different values are: [9, 5, 7]
# The full list including all items excluding doubles is: [0, 1, 2, 3, 4, 5, 7, 9]
# List without things that are not in night2: [0, 1, 2, 3, 4]

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ### Change a value in a dictionary (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given the Python dictionary:
#
# ```python
# planetsmass = { 'Mercury' : 0.33,
#                 'Venus'   : 4.87, 'Earth'   : 5.98,
#                 'Mars'    : 0.65, 'Jupiter' : 1900,
#                 'Saturn'  :  570, 'Uranus'  :  87,
#                 'Neptune' :  100, 'Pluto'   :  0.7 }
# ```
#
# 1. Extract from this dictionary a Python **list** with only the names of the objects.
# 1. Print the mass of Venus in Earth masses.
# 1. Remove Pluto from your dictionary.
# 1. Add Planet Nine with mass 29.3 to the dictionary.
# 1. Print the modified dictionary.
#
#
# **Answer**:

# %%
# Correction: changed printing venus and earths mass to printing venus IN earth masses
planetsmass = { 'Mercury' : 0.33,
                'Venus'   : 4.87, 'Earth'   : 5.98,
                'Mars'    : 0.65, 'Jupiter' : 1900,
                'Saturn'  :  570, 'Uranus'  :  87,
                'Neptune' :  100, 'Pluto'   :  0.7 }    # Create dictionary with names as keys and masses as values

keys = planetsmass.keys()  # Create a list with only the keys of the dictionary
print(f"list of keys: {list(keys)}") # Print the previously created list

venus_earthm = planetsmass['Venus'] / planetsmass['Earth'] # To get the mass of Venus in Earth masses we divide the mass of venus by the earths mass
print(f"Mass of Venus in Earth masses: {venus_earthm}") # Print the previously calculated mass of Venus in Earth masses

del planetsmass['Pluto'] # Delete the item from the dictionary with key 'Pluto', this will also delete the value
planetsmass.update({'Nine' : 29.3}) # Add new key and value to the dictionary
print(f"Dictionary without Pluto, added Nine: {planetsmass}") # Print the newly updated dictionary
# Out:
# list of keys: ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune', 'Pluto']
# Mass of Venus in Earth masses: 0.81438127090301
# Dictionary without Pluto, added Nine: {'Mercury': 0.33, 'Venus': 4.87, 'Earth': 5.98, 'Mars': 0.65, 'Jupiter': 1900, 'Saturn': 570, 'Uranus': 87, 'Neptune': 100, 'Nine': 29.3}

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ### Apply NumPy functions to data (2pt) <font color='red'><b>COURSEWORK</b></font>
#
# * Create a NumPy array `x` with 100 angles in degrees between 0 and 360 degrees using ``np.linspace()``
# * Calculate the ``np.sinc(x)`` values of ``x``, with ``x`` in radians. The definition of the sinc function is:
#
#   $$\mathrm{sinc}(x) = \frac{\sin(\pi x)}{\pi x}$$
#
# * Print the first 10 values of the result.
#
# **Answer**

# %%
import numpy as np   # Import library numpy with the alias np
from math import *   # Import all items from library math

angle_deg = np.linspace(0, 360, 100) # Make array of 100 numbers evenly spaced out between 0 and 360
angle_rad = np.deg2rad(angle_deg) # Convert all items in array to radians

sinc_values = np.sinc(angle_rad) # Calculates np.sinc for all values in angle_rad

print(f"The first 10 values in sinc_values are: {sinc_values[:10]}") # Print only first 10 values
# Out:
# The first 10 values in sinc_values are: [1.         0.99338737 0.97370676 0.94142562 0.89730831 0.84239452
#  0.77797001 0.70553048 0.62673987 0.5433841 ]

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ## Finishing up
#
# **Please read the section about your report in the task documentation very carefully before submitting it to BrightSpace.**
#
# ------------

# %% [markdown]
# ## T.A. Grading

# %%
# Leave unaltered
taskgrade = round(10*currentpoints/totalpoints, 1) if totalpoints != 0 else 0
print(f"Total number of points: {totalpoints}. Student score: {currentpoints}.  Task Grade = {taskgrade}")
# Out:
# Total number of points: 13. Student score: 0.0.  Task Grade = 0.0
